# %% [markdown]
# <a href="https://colab.research.google.com/github/tonycota/deep-learning-challenge/blob/main/optimized_notebooks/deep_learning_optimization1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# FIRST ATTEMPT AT OPTIMIZATION

# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME' and AFFILIATION/ STATUS/ ASK_AMT columns
columns_to_drop = ['EIN', 'NAME', 'AFFILIATION', 'STATUS', 'ASK_AMT']
application_df.drop(columns=columns_to_drop, inplace=True)
application_df.head(10)
# Out:
#   APPLICATION_TYPE CLASSIFICATION      USE_CASE  ORGANIZATION     INCOME_AMT  \
# 0              T10          C1000    ProductDev   Association              0
# 1               T3          C2000  Preservation  Co-operative         1-9999
# 2               T5          C3000    ProductDev   Association              0
# 3               T3          C2000  Preservation         Trust    10000-24999
# 4               T3          C1000     Heathcare         Trust  100000-499999
# 5               T3          C1200  Preservation         Trust              0
# 6               T3          C1000  Preservation         Trust  100000-499999
# 7               T3          C2000  Preservation         Trust        10M-50M
# 8               T7          C1000    ProductDev         Trust         1-9999
# 9               T5          C3000    ProductDev   Association              0
#
#   SPECIAL_CONSIDERATIONS  IS_SUCCESSFUL
# 0                      N              1
# 1                      N              1
# 2                      N              0
# 3                      N              1
# 4                      N              1
# 5                      N              1
# 6                      N              1
# 7                      N              1
# 8                      N              1
# 9                      N              0

# %%
# Determine the number of unique values in each column.
unique_values = application_df.nunique()
unique_values
# Out:
# APPLICATION_TYPE          17
# CLASSIFICATION            71
# USE_CASE                   5
# ORGANIZATION               4
# INCOME_AMT                 9
# SPECIAL_CONSIDERATIONS     2
# IS_SUCCESSFUL              2
# dtype: int64

# %%
print(application_df.value_counts())
# Out:
# APPLICATION_TYPE  CLASSIFICATION  USE_CASE      ORGANIZATION  INCOME_AMT     SPECIAL_CONSIDERATIONS  IS_SUCCESSFUL
# T3                C1000           Preservation  Trust         0              N                       1                4014
#                                                                                                      0                2495
#                   C2000           Preservation  Trust         0              N                       1                1361
#                                                                                                      0                1235
#                   C1200           Preservation  Association   0              N                       0                1184
#                                                                                                                       ...
#                   C2500           Preservation  Trust         0              N                       1                   1
#                   C2561           Preservation  Trust         25000-99999    N                       1                   1
#                   C2570           Preservation  Trust         100000-499999  N                       1                   1
#                   C2600           Preservation  Trust         0              N                       0                   1
# T9                C2000           ProductDev    Trust         1M-5M          N                       1                   1
# Name: count, Length: 1092, dtype: int64

# %%
# Look at APPLICATION_TYPE value counts to identify and replace with "Other"
app_counts = application_df["APPLICATION_TYPE"].value_counts()
app_counts
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = list(app_counts[app_counts < 500].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure replacement was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts to identify and replace with "Other"
classy_counts = application_df["CLASSIFICATION"].value_counts()
classy_counts
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
helpful_classy_counts = classy_counts.loc[classy_counts > 1]
helpful_classy_counts[:15]
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(classy_counts[classy_counts < 1000].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure replacement was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: count, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
app_numeric = pd.get_dummies(application_df)
app_numeric
# Out:
#        IS_SUCCESSFUL  APPLICATION_TYPE_Other  APPLICATION_TYPE_T10  \
# 0                  1                   False                  True
# 1                  1                   False                 False
# 2                  0                   False                 False
# 3                  1                   False                 False
# 4                  1                   False                 False
# ...              ...                     ...                   ...
# 34294              0                   False                 False
# 34295              0                   False                 False
# 34296              0                   False                 False
# 34297              1                   False                 False
# 34298              0                   False                 False
#
#        APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  APPLICATION_TYPE_T4  \
# 0                     False                False                False
# 1                     False                 True                False
# 2                     False                False                False
# 3                     False                 True                False
# 4                     False                 True                False
# ...                     ...                  ...                  ...
# 34294                 False                False                 True
# 34295                 False                False                 True
# 34296                 False                 True                False
# 34297                 False                False                False
# 34298                 False                 True                False
#
#        APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  APPLICATION_TYPE_T7  \
# 0                    False                False                False
# 1                    False                False                False
# 2                     True                False                False
# 3                    False                False                False
# 4                    False                False                False
# ...                    ...                  ...                  ...
# 34294                False                False                False
# 34295                False                False                False
# 34296                False                False                False
# 34297                 True                False                False
# 34298                False                False                False
#
#        APPLICATION_TYPE_T8  ...  INCOME_AMT_1-9999  INCOME_AMT_10000-24999  \
# 0                    False  ...              False                   False
# 1                    False  ...               True                   False
# 2                    False  ...              False                   False
# 3                    False  ...              False                    True
# 4                    False  ...              False                   False
# ...                    ...  ...                ...                     ...
# 34294                False  ...              False                   False
# 34295                False  ...              False                   False
# 34296                False  ...              False                   False
# 34297                False  ...              False                   False
# 34298                False  ...              False                   False
#
#        INCOME_AMT_100000-499999  INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  \
# 0                         False               False             False
# 1                         False               False             False
# 2                         False               False             False
# 3                         False               False             False
# 4                          True               False             False
# ...                         ...                 ...               ...
# 34294                     False               False             False
# 34295                     False               False             False
# 34296                     False               False             False
# 34297                     False               False             False
# 34298                     False               False              True
#
#        INCOME_AMT_25000-99999  INCOME_AMT_50M+  INCOME_AMT_5M-10M  \
# 0                       False            False              False
# 1                       False            False              False
# 2                       False            False              False
# 3                       False            False              False
# 4                       False            False              False
# ...                       ...              ...                ...
# 34294                   False            False              False
# 34295                   False            False              False
# 34296                   False            False              False
# 34297                   False            False              False
# 34298                   False            False              False
#
#        SPECIAL_CONSIDERATIONS_N  SPECIAL_CONSIDERATIONS_Y
# 0                          True                     False
# 1                          True                     False
# 2                          True                     False
# 3                          True                     False
# 4                          True                     False
# ...                         ...                       ...
# 34294                      True                     False
# 34295                      True                     False
# 34296                      True                     False
# 34297                      True                     False
# 34298                      True                     False
#
# [34299 rows x 36 columns]

# %%
# Split our preprocessed data into our features and target arrays
X = app_numeric.drop('IS_SUCCESSFUL', axis=1)
y = app_numeric['IS_SUCCESSFUL']

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 =  15
hidden_nodes_layer2 = 15

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="tanh"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="tanh"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 15)                540
#
#  dense_4 (Dense)             (None, 15)                240
#
#  dense_5 (Dense)             (None, 1)                 16
#
# =================================================================
# Total params: 796 (3.11 KB)
# Trainable params: 796 (3.11 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 3s 2ms/step - loss: 0.6388 - accuracy: 0.6314
# Epoch 2/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6178 - accuracy: 0.6524
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6133 - accuracy: 0.6546
# Epoch 4/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6114 - accuracy: 0.6536
# Epoch 5/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6102 - accuracy: 0.6556
# Epoch 6/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6091 - accuracy: 0.6534
# Epoch 7/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6083 - accuracy: 0.6550
# Epoch 8/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6080 - accuracy: 0.6557
# Epoch 9/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6073 - accuracy: 0.6568
# Epoch 10/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6073 - accuracy: 0.6556
# Epoch 11/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6069 - accuracy: 0.6551
# Epoch 12/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6066 - accuracy: 0.6570
# Epoch 13/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6063 - accuracy: 0.6571
# Epoch 14/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6061 - accuracy: 0.6549
# Epoch 15/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6061 - accuracy: 0.6555
# Epoch 16/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6053 - accuracy: 0.6567
# Epoch 17/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6056 - accuracy: 0.6572
# Epoch 18/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6056 - accuracy: 0.6559
# Epoch 19/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6050 - accuracy: 0.6575
# Epoch 20/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6046 - accuracy: 0.6564
# Epoch 21/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6048 - accuracy: 0.6581
# Epoch 22/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6046 - accuracy: 0.6571
# Epoch 23/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6049 - accuracy: 0.6575
# Epoch 24/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6043 - accuracy: 0.6579
# Epoch 25/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6042 - accuracy: 0.6571
# Epoch 26/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6044 - accuracy: 0.6577
# Epoch 27/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6043 - accuracy: 0.6586
# Epoch 28/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6040 - accuracy: 0.6570
# Epoch 29/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6037 - accuracy: 0.6582
# Epoch 30/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6040 - accuracy: 0.6581
# Epoch 31/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6038 - accuracy: 0.6565
# Epoch 32/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6035 - accuracy: 0.6581
# Epoch 33/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6035 - accuracy: 0.6582
# Epoch 34/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6035 - accuracy: 0.6579
# Epoch 35/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6035 - accuracy: 0.6566
# Epoch 36/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6034 - accuracy: 0.6594
# Epoch 37/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6029 - accuracy: 0.6573
# Epoch 38/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6032 - accuracy: 0.6573
# Epoch 39/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6029 - accuracy: 0.6571
# Epoch 40/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6028 - accuracy: 0.6577
# Epoch 41/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6028 - accuracy: 0.6583
# Epoch 42/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6030 - accuracy: 0.6578
# Epoch 43/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6027 - accuracy: 0.6601
# Epoch 44/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6024 - accuracy: 0.6577
# Epoch 45/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6025 - accuracy: 0.6574
# Epoch 46/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6025 - accuracy: 0.6585
# Epoch 47/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6024 - accuracy: 0.6580
# Epoch 48/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6024 - accuracy: 0.6586
# Epoch 49/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6022 - accuracy: 0.6601
# Epoch 50/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6024 - accuracy: 0.6597
# Epoch 51/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6022 - accuracy: 0.6590
# Epoch 52/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6020 - accuracy: 0.6600
# Epoch 53/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6022 - accuracy: 0.6595
# Epoch 54/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6022 - accuracy: 0.6586
# Epoch 55/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6019 - accuracy: 0.6589
# Epoch 56/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6021 - accuracy: 0.6594
# Epoch 57/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6020 - accuracy: 0.6574
# Epoch 58/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6019 - accuracy: 0.6589
# Epoch 59/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6015 - accuracy: 0.6603
# Epoch 60/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6018 - accuracy: 0.6579
# Epoch 61/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6014 - accuracy: 0.6598
# Epoch 62/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6016 - accuracy: 0.6585
# Epoch 63/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6014 - accuracy: 0.6597
# Epoch 64/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6015 - accuracy: 0.6600
# Epoch 65/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6015 - accuracy: 0.6595
# Epoch 66/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6017 - accuracy: 0.6600
# Epoch 67/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6013 - accuracy: 0.6588
# Epoch 68/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6013 - accuracy: 0.6602
# Epoch 69/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6011 - accuracy: 0.6611
# Epoch 70/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6016 - accuracy: 0.6574
# Epoch 71/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6013 - accuracy: 0.6599
# Epoch 72/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6014 - accuracy: 0.6603
# Epoch 73/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6012 - accuracy: 0.6606
# Epoch 74/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6013 - accuracy: 0.6585
# Epoch 75/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6013 - accuracy: 0.6589
# Epoch 76/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6011 - accuracy: 0.6586
# Epoch 77/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6013 - accuracy: 0.6596
# Epoch 78/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6009 - accuracy: 0.6594
# Epoch 79/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6010 - accuracy: 0.6593
# Epoch 80/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6009 - accuracy: 0.6590
# Epoch 81/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6010 - accuracy: 0.6592
# Epoch 82/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6007 - accuracy: 0.6591
# Epoch 83/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6010 - accuracy: 0.6602
# Epoch 84/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6007 - accuracy: 0.6607
# Epoch 85/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6008 - accuracy: 0.6612
# Epoch 86/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6007 - accuracy: 0.6604
# Epoch 87/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6008 - accuracy: 0.6588
# Epoch 88/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6003 - accuracy: 0.6600
# Epoch 89/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6005 - accuracy: 0.6586
# Epoch 90/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6006 - accuracy: 0.6595
# Epoch 91/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6005 - accuracy: 0.6604
# Epoch 92/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6006 - accuracy: 0.6592
# Epoch 93/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6005 - accuracy: 0.6604
# Epoch 94/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6003 - accuracy: 0.6603
# Epoch 95/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6004 - accuracy: 0.6607
# Epoch 96/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6004 - accuracy: 0.6599
# Epoch 97/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6006 - accuracy: 0.6601
# Epoch 98/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6001 - accuracy: 0.6598
# Epoch 99/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6003 - accuracy: 0.6606
# Epoch 100/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6001 - accuracy: 0.6604

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.6122 - accuracy: 0.6552 - 425ms/epoch - 2ms/step
# Loss: 0.6122379302978516, Accuracy: 0.6551603674888611

# %%
# Export our model to HDF5 file
# Working in google colab so the code gets interesting here
# import os dependency
import os
desktop_path = os.path.join(os.path.expanduser("~"), "Desktop")
file_path = os.path.join(desktop_path, "AlphabetSoupCharity_2.h5")
nn.save(file_path)

# save file from google colab
from google.colab import files
files.download(file_path)
# Ensure file was saved into correct directory
print(f"Model saved to {file_path}")
# Out:
# Model saved to /root/Desktop/AlphabetSoupCharity_2.h5

# %%
# This attempt at optimization did NOT work the accuracy score went down to 65%
